# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import pylab as pl
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ## Load Data

# %%
codefault = pd.read_csv("C:/Users/LucasFranklin/Desktop/Data Mining/Codes/Data-Mining/DataSets/ccdefault.csv")

# %%
codefault.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#     ...     BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0   ...             0          0          0         0       689         0
# 1   ...          3272       3455       3261         0      1000      1000
# 2   ...         14331      14948      15549      1518      1500      1000
# 3   ...         28314      28959      29547      2000      2019      1200
# 4   ...         20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  DEFAULT
# ...

# %%
codefault.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
list(codefault.columns.values)
# Out:
# ['ID',
#  'LIMIT_BAL',
#  'SEX',
#  'EDUCATION',
#  'MARRIAGE',
#  'AGE',
#  'PAY_0',
#  'PAY_2',
#  'PAY_3',
#  'PAY_4',
#  'PAY_5',
#  'PAY_6',
#  'BILL_AMT1',
#  'BILL_AMT2',
#  'BILL_AMT3',
#  'BILL_AMT4',
#  'BILL_AMT5',
#  'BILL_AMT6',
#  'PAY_AMT1',
#  'PAY_AMT2',
#  'PAY_AMT3',
#  'PAY_AMT4',
#  'PAY_AMT5',
#  'PAY_AMT6',
#  'DEFAULT']

# %% [markdown]
# Create new dataset without id variableas

# %%
ccd = codefault[codefault.columns[1:]]
list(ccd.columns.values)
# Out:
# ['LIMIT_BAL',
#  'SEX',
#  'EDUCATION',
#  'MARRIAGE',
#  'AGE',
#  'PAY_0',
#  'PAY_2',
#  'PAY_3',
#  'PAY_4',
#  'PAY_5',
#  'PAY_6',
#  'BILL_AMT1',
#  'BILL_AMT2',
#  'BILL_AMT3',
#  'BILL_AMT4',
#  'BILL_AMT5',
#  'BILL_AMT6',
#  'PAY_AMT1',
#  'PAY_AMT2',
#  'PAY_AMT3',
#  'PAY_AMT4',
#  'PAY_AMT5',
#  'PAY_AMT6',
#  'DEFAULT']

# %% [markdown]
# ## Split data for Learning and Training

# %%
test_idx = np.random.uniform(0,1, len(ccd)) <= .333
train = ccd[test_idx == True]
test = ccd[test_idx == False]

# %%
train.head()
# Out:
#     LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 1      120000    2          2         2   26     -1      2      0      0
# 2       90000    2          2         2   34      0      0      0      0
# 7      100000    2          2         2   23      0     -1     -1      0
# 8      140000    2          3         1   28      0      0      2      0
# 12     630000    2          2         2   41     -1      0     -1     -1
#
#     PAY_5   ...     BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 1       0   ...          3272       3455       3261         0      1000
# 2       0   ...         14331      14948      15549      1518      1500
# 7       0   ...           221       -159        567       380       601
# 8       0   ...         12211      11793       3719      3329         0
# 12     -1   ...          6500       6500       2870      1000      6500
#
#     PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  DEFAULT
# ...

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Specify features used to predict classification

# %%
features = ['LIMIT_BAL',
 'SEX',
 'EDUCATION',
 'MARRIAGE',
 'AGE',
 'PAY_0',
 'PAY_2',
 'PAY_3',
 'PAY_4',
 'PAY_5',
 'PAY_6',
 'BILL_AMT1',
 'BILL_AMT2',
 'BILL_AMT3',
 'BILL_AMT4',
 'BILL_AMT5',
 'BILL_AMT6',
 'PAY_AMT1',
 'PAY_AMT2',
 'PAY_AMT3',
 'PAY_AMT4',
 'PAY_AMT5',
 'PAY_AMT6',
 'DEFAULT']

# %% [markdown]
# ### KNN Classification

# %%
n = 9

results = []

clf = KNeighborsClassifier(n_neighbors = n)

clf.fit(train[features], train['DEFAULT'])

preds = clf.predict(test[features])
accuracy = np.where(preds == test['DEFAULT'],1,0).sum() / float(len(test))*100

# %%
print("Neighbors: %d, Accuracy: %2d%%" % (n, round(accuracy, 2)))
# Out:
# Neighbors: 9, Accuracy: 76%
